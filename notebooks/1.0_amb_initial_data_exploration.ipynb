# %%
import pandas as pd
import numpy as np
import scipy as sp
import os

# %% [markdown]
# # Loading The data set

# %%
# !make --directory="../" data
# Out:
# make: Entering directory '/home/mahdi/Documents/Projects/household_expenditure_pca'
# python household_expenditure_pca/dataset.py
# 2025-02-22 14:43:22.141 | INFO     | config:<module>:11 - PROJ_ROOT path is: /home/mahdi/Documents/Projects/household_expenditure_pca
# 2025-02-22 14:43:22.146 | INFO     | __main__:main:17 - Fetching Hugging Face dataset 'CODE-BLOCK/Weekly_household_expenditure'...
# 2025-02-22 14:43:24.556 | SUCCESS  | __main__:main:22 - Downloading dataset complete.
# 2025-02-22 14:43:24.557 | INFO     | __main__:main:23 - You can find the data set in /home/mahdi/Documents/Projects/household_expenditure_pca/data/raw/dataset.csv
# make: Leaving directory '/home/mahdi/Documents/Projects/household_expenditure_pca'

# %%
expenditures = pd.read_csv("../data/raw/dataset.csv")
expenditures.set_index(expenditures.columns[0], inplace=True)
expenditures.index.name = None
expenditures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Household_Weekly_Expenditure    3362 non-null   object
#  1   Monthly_Household_Income        3536 non-null   object
#  2   Number_of_Household_Dependents  3537 non-null   float64
#  3   Age_of_Head_of_Household        3609 non-null   float64
#  4   Household_Size                  3606 non-null   float64
#  5   Education_Level                 3611 non-null   object
#  6   Employment_Status               3613 non-null   object
#  7   Location                        3606 non-null   object
#  8   Savings_Rate                    3612 non-null   float64
#  9   Weekly_Savings                  3610 non-null   float64
#  10  Monthly_Rent                    3610 non-null   object
#  11  Loan_Repayment                  3611 non-null   float64
# ...

# %%
expenditures
# Out:
#      Household_Weekly_Expenditure Monthly_Household_Income  \
# 0                             NaN                      NaN
# 1                          553.82                 4,958.45
# 2                          710.45                 6,459.93
# 3                          639.76                 6,871.41
# 4                          473.14                 4,783.66
# ...                           ...                      ...
# 3995                       548.94                 5,265.78
# 3996                       294.54                 2,291.26
# 3997                       406.19                 4,579.98
# 3998                       787.65                 7,630.61
# 3999                       547.84                 4,805.76
#
#       Number_of_Household_Dependents  Age_of_Head_of_Household  \
# 0                                5.0                      38.0
# 1                                3.0                      59.0
# 2                                6.0                      53.0
# ...
